# %%
import cv2
import numpy as np

# %%
'''
    drawMarker(...)
        drawMarker(dictionary, id, sidePixels[, img[, borderBits]]) -> img
'''

aruco = cv2.aruco
aruco_dict = aruco.Dictionary_get(aruco.DICT_6X6_250)
print(aruco_dict)
# second parameter is id number
# last parameter is total image size
img = aruco.drawMarker(aruco_dict, 2, 700)
cv2.imwrite("test_marker.jpg", img)
 
cv2.imshow('frame',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <aruco_Dictionary 0x11a124570>

# %%
cap = cv2.VideoCapture(0)
 
while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()
    #print(frame.shape) #480x640
    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    aruco_dict = aruco.Dictionary_get(aruco.DICT_6X6_250)
    parameters =  aruco.DetectorParameters_create()
 
    #print(parameters)
 
    '''    detectMarkers(...)
        detectMarkers(image, dictionary[, corners[, ids[, parameters[, rejectedI
        mgPoints]]]]) -> corners, ids, rejectedImgPoints
        '''
        #lists of ids and the corners beloning to each id
    corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, aruco_dict, parameters=parameters)
    if len(corners) > 0:
        print(corners)
 
    #It's working.
    # my problem was that the cellphone put black all around it. The alrogithm
    # depends very much upon finding rectangular black blobs
 
    gray = aruco.drawDetectedMarkers(gray, corners)
 
    #print(rejectedImgPoints)
    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
 
# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# [array([[[357., 182.],
#         [585., 226.],
#         [544., 443.],
#         [321., 400.]]], dtype=float32)]
# [array([[[343., 210.],
#         [559., 246.],
#         [528., 455.],
#         [314., 422.]]], dtype=float32)]
# [array([[[338., 219.],
#         [554., 243.],
#         [536., 448.],
#         [328., 432.]]], dtype=float32)]
# [array([[[355., 228.],
#         [573., 241.],
#         [565., 452.],
#         [347., 444.]]], dtype=float32)]
# [array([[[366., 268.],
#         [565., 257.],
#         [584., 447.],
#         [381., 467.]]], dtype=float32)]
# [array([[[314., 329.],
#         [476., 314.],
#         [508., 467.],
#         [340., 496.]]], dtype=float32)]
# [array([[[324., 328.],
#         [503., 320.],
#         [515., 478.],
#         [341., 494.]]], dtype=float32)]
# [array([[[359., 323.],
#         [520., 324.],
#         [527., 489.],
#         [354., 492.]]], dtype=float32)]
# [array([[[370., 327.],
#         [537., 329.],
#         [538., 496.],
#         [363., 496.]]], dtype=float32)]
# [array([[[381., 328.],
#         [551., 327.],
#         [556., 492.],
#         [381., 500.]]], dtype=float32)]
# [array([[[382., 330.],
#         [554., 320.],
#         [570., 481.],
#         [395., 501.]]], dtype=float32)]
# [array([[[390., 321.],
#         [560., 305.],
#         [591., 462.],
#         [410., 489.]]], dtype=float32)]
# [array([[[402., 301.],
#         [570., 283.],
#         [597., 440.],
#         [418., 460.]]], dtype=float32)]
# [array([[[416., 257.],
#         [589., 250.],
#         [606., 409.],
#         [423., 420.]]], dtype=float32)]
# [array([[[430., 236.],
#         [598., 235.],
#         [606., 407.],
#         [422., 404.]]], dtype=float32)]
# [array([[[440.,  67.],
#         [688., 109.],
#         [668., 351.],
#         [418., 322.]]], dtype=float32)]
# [array([[[451., 121.],
#         [685., 149.],
#         [673., 376.],
#         [436., 357.]]], dtype=float32)]
# [array([[[447., 151.],
#         [665., 180.],
#         [665., 395.],
#         [440., 392.]]], dtype=float32)]
# [array([[[436., 194.],
#         [631., 208.],
#         [656., 405.],
#         [442., 418.]]], dtype=float32)]
# [array([[[404., 265.],
#         [583., 248.],
#         [626., 422.],
#         [437., 455.]]], dtype=float32)]
# [array([[[384., 306.],
#         [551., 287.],
#         [587., 448.],
#         [414., 478.]]], dtype=float32)]
# [array([[[377., 322.],
#         [540., 302.],
#         [575., 458.],
#         [405., 488.]]], dtype=float32)]
# [array([[[372., 333.],
#         [534., 310.],
#         [571., 464.],
#         [402., 496.]]], dtype=float32)]
# [array([[[370., 348.],
#         [526., 317.],
#         [573., 464.],
#         [415., 506.]]], dtype=float32)]
# [array([[[370., 462.],
#         [488., 391.],
#         [562., 504.],
#         [453., 575.]]], dtype=float32)]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-9712efd08364> in <module>()
#      17         '''
#      18         #lists of ids and the corners beloning to each id
# ---> 19     corners, ids, rejectedImgPoints = aruco.detectMarkers(gray, aruco_dict, parameters=parameters)
#      20     if len(corners) > 0:
#      21         print(corners)
#
# KeyboardInterrupt:
